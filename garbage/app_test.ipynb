# %%
from ApplicationKernel import AppServer
import time
import matplotlib.pyplot as plt

app = AppServer("app_test")
nanonis = app.addInstrument('inst_nanonis')
nanonisUDP = app.addInstrument('inst_nanonisUDP')

t=[]
for i in range(100):
    t.append(nanonisUDP.query("get_time()"))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(t, 'r-')
del app
# Out:
# Exception ignored in: <function Coordinator.__del__ at 0x000001DF45576660>
# Traceback (most recent call last):
#   File "c:\Users\VFSTM-PC3\Documents\InstrumentHub\InstrumentHub\ApplicationKernel.py", line 46, in __del__
#     self.port_app_inst.close()
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: 'Coordinator' object has no attribute 'port_app_inst'
